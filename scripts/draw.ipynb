# %%
import pandas as pd
import matplotlib.pyplot as plt

disney_sh =  pd.read_csv('../data/disney_shanghai.csv')
disney_sh
# Out:
#                                      Name      Ride type  \
# 0                          Camp Discovery     Attraction
# 1      Challenge Trails at Camp Discovery     Attraction
# 2           Vista Trail at Camp Discovery     Attraction
# 3                Soaring Over the Horizon     Attraction
# 4            “Once Upon a Time” Adventure     Attraction
# ..                                    ...            ...
# 124       Catch a Glimpse of Jack Sparrow  Entertainment
# 125  Hundred Acre Wood Character Sighting  Entertainment
# 126            Princess Balcony Greetings  Entertainment
# 127      Avengers Assemble at the E-Stage  Entertainment
# 128                 Woody’s Rescue Patrol  Entertainment
#
#                                 Time  Fastpass-avaliable     Status  \
# 0    2020-08-31T13:38:47.638019+0800               False  Operating
# 1    2020-08-31T13:38:47.638035+0800               False  Operating
# 2    2020-08-31T13:38:47.638039+0800               False  Operating
# ...

# %%
disney_sh.dropna()
# Out:
#                                                  Name   Ride type  \
# 0                                      Camp Discovery  Attraction
# 1                  Challenge Trails at Camp Discovery  Attraction
# 3                            Soaring Over the Horizon  Attraction
# 4                        “Once Upon a Time” Adventure  Attraction
# 5                            Alice in Wonderland Maze  Attraction
# 7                                      Hunny Pot Spin  Attraction
# 8                                  Peter Pan’s Flight  Attraction
# 9                             Seven Dwarfs Mine Train  Attraction
# 10             The Many Adventures of Winnie the Pooh  Attraction
# 11                       Voyage to the Crystal Grotto  Attraction
# 12                          Dumbo the Flying Elephant  Attraction
# 13                                  Fantasia Carousel  Attraction
# 14  TRON Lightcycle Power Run – Presented by Chevr...  Attraction
# ...

# %%
disney_sh.groupby('Time').mean()
# Out:
#                                  Fastpass-avaliable  Wait time  Temperature  \
# Time
# 2020-08-31T13:38:47.638019+0800               False        0.0        33.28
# 2020-08-31T13:38:47.638035+0800               False       10.0        33.28
# 2020-08-31T13:38:47.638039+0800               False        NaN        33.28
# 2020-08-31T13:38:47.638047+0800                True       60.0        33.28
# 2020-08-31T13:38:47.638051+0800               False        5.0        33.28
# ...                                             ...        ...          ...
# 2020-08-31T23:53:02.775426+0800               False        NaN        28.20
# 2020-08-31T23:53:02.775429+0800               False        NaN        28.20
# 2020-08-31T23:53:02.775431+0800               False        NaN        28.20
# 2020-08-31T23:53:02.775434+0800               False        NaN        28.20
# 2020-08-31T23:53:02.775437+0800               False        NaN        28.20
#
# ...
